# %%
import pandas as pd

# %%
df = pd.read_csv('Visadataset.csv')
df.head(5)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
data = df.to_dict(orient="records")
data
# Out:
# [{'case_id': 'EZYV01',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 14513,
#   'yr_of_estab': 2007,
#   'region_of_employment': 'West',
#   'prevailing_wage': 592.2029,
#   'unit_of_wage': 'Hour',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV02',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2412,
#   'yr_of_estab': 2002,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 83425.65,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV03',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'Y',
#   'no_of_employees': 44444,
#   'yr_of_estab': 2008,
#   'region_of_employment': 'West',
# ...

# %%
from pymongo.mongo_client import MongoClient
uri = "mongodb+srv://srinukto:srinukto1@cluster0.ojp3gww.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
# Create a new client and connect to the server
client = MongoClient(uri)
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
data_base = client['US_VISA']
collection = data_base['visa_data']
collection.insert_many(data)
# Out:
# InsertManyResult([ObjectId('6802fa1d84fb6fca4b0f50b4'), ObjectId('6802fa1d84fb6fca4b0f50b5'), ObjectId('6802fa1d84fb6fca4b0f50b6'), ObjectId('6802fa1d84fb6fca4b0f50b7'), ObjectId('6802fa1d84fb6fca4b0f50b8'), ObjectId('6802fa1d84fb6fca4b0f50b9'), ObjectId('6802fa1d84fb6fca4b0f50ba'), ObjectId('6802fa1d84fb6fca4b0f50bb'), ObjectId('6802fa1d84fb6fca4b0f50bc'), ObjectId('6802fa1d84fb6fca4b0f50bd'), ObjectId('6802fa1d84fb6fca4b0f50be'), ObjectId('6802fa1d84fb6fca4b0f50bf'), ObjectId('6802fa1d84fb6fca4b0f50c0'), ObjectId('6802fa1d84fb6fca4b0f50c1'), ObjectId('6802fa1d84fb6fca4b0f50c2'), ObjectId('6802fa1d84fb6fca4b0f50c3'), ObjectId('6802fa1d84fb6fca4b0f50c4'), ObjectId('6802fa1d84fb6fca4b0f50c5'), ObjectId('6802fa1d84fb6fca4b0f50c6'), ObjectId('6802fa1d84fb6fca4b0f50c7'), ObjectId('6802fa1d84fb6fca4b0f50c8'), ObjectId('6802fa1d84fb6fca4b0f50c9'), ObjectId('6802fa1d84fb6fca4b0f50ca'), ObjectId('6802fa1d84fb6fca4b0f50cb'), ObjectId('6802fa1d84fb6fca4b0f50cc'), ObjectId('6802fa1d84fb6fca4b0f
# ...

# %%
new_df = pd.DataFrame(list(collection.find()))
new_df.drop(columns=['_id'], inplace=True)

# %%
new_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...
